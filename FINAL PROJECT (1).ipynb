# %% [markdown]
# The project aims to examine patterns, relationships, and trends within the dataset to understand how factors such as work environment, workload, work-life balance, and communication influence employees psychological well-being.The goal is to generate meaningful insights that can help organizations and policymakers to understand better the challenges associated with remote work and develop strategies to improve employee well-being and workplace productivity.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Data Loading and Initial Overview
# Loading the edited file since original file had no missing values so created one with some missing values.

# %%
rw=pd.read_csv(("C:/Users/User/Downloads/edited remote work.csv"))

# %%
rw
# Out:
#      Employee_ID   Age             Gender           Job_Role    Industry  \
# 0        EMP0001  32.0         Non-binary                 HR  Healthcare
# 1        EMP0002  40.0             Female     Data Scientist          IT
# 2        EMP0003  59.0         Non-binary  Software Engineer   Education
# 3        EMP0004  27.0               Male  Software Engineer     Finance
# 4        EMP0005  49.0               Male              Sales  Consulting
# ...          ...   ...                ...                ...         ...
# 2495     EMP2496  31.0               Male     Data Scientist          IT
# 2496     EMP2497  55.0  Prefer not to say  Software Engineer   Education
# 2497     EMP2498  47.0               Male    Project Manager          IT
# 2498     EMP2499  56.0             Female     Data Scientist  Healthcare
# 2499     EMP0001  32.0         Non-binary                 HR  Healthcare
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                    13.0        Hybrid                   47.0
# 1                     3.0        Remote                   52.0
# 2                    22.0        Hybrid                   46.0
# 3                    20.0        Onsite                   32.0
# 4                    32.0        Onsite                   35.0
# ...                   ...           ...                    ...
# 2495                 20.0        Onsite                   48.0
# 2496                 15.0        Onsite                   41.0
# 2497                 19.0        Onsite                   27.0
# 2498                 18.0        Remote                   21.0
# 2499                 13.0        Hybrid                   47.0
#
#       Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                            7.0                       2.0       Medium
# 1                            4.0                       1.0       Medium
# 2                            NaN                       5.0       Medium
# 3                            8.0                       4.0         High
# 4                           12.0                       2.0         High
# ...                          ...                       ...          ...
# 2495                         0.0                       1.0         High
# 2496                        15.0                       3.0          Low
# 2497                         7.0                       3.0          Low
# 2498                        13.0                       2.0       Medium
# 2499                         7.0                       2.0       Medium
#
#      Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0                 Depression                                No
# 1                    Anxiety                                No
# 2                    Anxiety                                No
# 3                 Depression                               Yes
# 4                        NaN                               Yes
# ...                      ...                               ...
# 2495                 Anxiety                               Yes
# 2496                 Anxiety                                No
# 2497                 Burnout                               Yes
# 2498              Depression                                No
# 2499              Depression                                No
#
#      Productivity_Change Satisfaction_with_Remote_Work  \
# 0               Decrease                   Unsatisfied
# 1               Increase                     Satisfied
# 2              No Change                   Unsatisfied
# 3               Increase                   Unsatisfied
# 4               Decrease                   Unsatisfied
# ...                  ...                           ...
# 2495            Increase                   Unsatisfied
# 2496           No Change                   Unsatisfied
# 2497            Increase                       Neutral
# 2498            Increase                       Neutral
# 2499            Decrease                   Unsatisfied
#
#       Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                   1            Weekly          Good
# 1                                   2            Weekly          Good
# 2                                   5               NaN          Poor
# 3                                   3               NaN          Poor
# 4                                   3            Weekly       Average
# ...                               ...               ...           ...
# 2495                                3             Daily          Good
# 2496                                5            Weekly          Good
# 2497                                4            Weekly       Average
# 2498                                3             Daily          Good
# 2499                                1            Weekly          Good
#
#              Region
# 0            Europe
# 1              Asia
# 2     North America
# 3            Europe
# 4     North America
# ...             ...
# 2495           Asia
# 2496        Oceania
# 2497  South America
# 2498        Oceania
# 2499         Europe
#
# [2500 rows x 19 columns]

# %%
#Number of rows and columns
print("shape of the dataset: ",rw.shape)
# Out:
# shape of the dataset:  (2500, 19)

# %%
#data type of columns
print("data type of each column:\n")
rw.dtypes
# Out:
# data type of each column:
# Employee_ID                           object
# Age                                  float64
# Gender                                object
# Job_Role                              object
# Industry                              object
# Years_of_Experience                  float64
# Work_Location                         object
# Hours_Worked_Per_Week                float64
# Number_of_Virtual_Meetings           float64
# Work_Life_Balance_Rating             float64
# Stress_Level                          object
# Mental_Health_Condition               object
# Access_to_Mental_Health_Resources     object
# Productivity_Change                   object
# Satisfaction_with_Remote_Work         object
# Company_Support_for_Remote_Work        int64
# Physical_Activity                     object
# Sleep_Quality                         object
# Region                                object
# dtype: object

# %% [markdown]
# Initial Observation:

# %%
rw.head()
# Out:
#   Employee_ID   Age      Gender           Job_Role    Industry  \
# 0     EMP0001  32.0  Non-binary                 HR  Healthcare
# 1     EMP0002  40.0      Female     Data Scientist          IT
# 2     EMP0003  59.0  Non-binary  Software Engineer   Education
# 3     EMP0004  27.0        Male  Software Engineer     Finance
# 4     EMP0005  49.0        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                 13.0        Hybrid                   47.0
# 1                  3.0        Remote                   52.0
# 2                 22.0        Hybrid                   46.0
# 3                 20.0        Onsite                   32.0
# 4                 32.0        Onsite                   35.0
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                         7.0                       2.0       Medium
# 1                         4.0                       1.0       Medium
# 2                         NaN                       5.0       Medium
# 3                         8.0                       4.0         High
# 4                        12.0                       2.0         High
#
#   Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0              Depression                                No
# 1                 Anxiety                                No
# 2                 Anxiety                                No
# 3              Depression                               Yes
# 4                     NaN                               Yes
#
#   Productivity_Change Satisfaction_with_Remote_Work  \
# 0            Decrease                   Unsatisfied
# 1            Increase                     Satisfied
# 2           No Change                   Unsatisfied
# 3            Increase                   Unsatisfied
# 4            Decrease                   Unsatisfied
#
#    Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                1            Weekly          Good
# 1                                2            Weekly          Good
# 2                                5               NaN          Poor
# 3                                3               NaN          Poor
# 4                                3            Weekly       Average
#
#           Region
# 0         Europe
# 1           Asia
# 2  North America
# 3         Europe
# 4  North America

# %%
rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        2500 non-null   object
#  1   Age                                2498 non-null   float64
#  2   Gender                             2500 non-null   object
#  3   Job_Role                           2498 non-null   object
#  4   Industry                           2498 non-null   object
#  5   Years_of_Experience                2497 non-null   float64
#  6   Work_Location                      2497 non-null   object
#  7   Hours_Worked_Per_Week              2494 non-null   float64
#  8   Number_of_Virtual_Meetings         2496 non-null   float64
#  9   Work_Life_Balance_Rating           2498 non-null   float64
#  10  Stress_Level                       2500 non-null   object
#  11  Mental_Health_Condition            1905 non-null   object
#  12  Access_to_Mental_Health_Resources  2497 non-null   object
#  13  Productivity_Change                2499 non-null   object
#  14  Satisfaction_with_Remote_Work      2497 non-null   object
#  15  Company_Support_for_Remote_Work    2500 non-null   int64
#  16  Physical_Activity                  1667 non-null   object
#  17  Sleep_Quality                      2500 non-null   object
#  18  Region                             2500 non-null   object
# dtypes: float64(5), int64(1), object(13)
# memory usage: 371.2+ KB

# %%
rw.describe()
# Out:
#                Age  Years_of_Experience  Hours_Worked_Per_Week  \
# count  2498.000000          2497.000000            2494.000000
# mean     41.104484            17.723268              39.471933
# std      11.295707             9.993944              11.829202
# min      22.000000             1.000000              20.000000
# 25%      31.000000             9.000000              29.000000
# 50%      41.000000            18.000000              39.000000
# 75%      51.000000            26.000000              50.000000
# max      60.000000            35.000000              60.000000
#
#        Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# count                 2496.000000               2498.000000
# mean                     7.602564                  2.992394
# std                      4.619717                  1.393223
# min                      0.000000                  1.000000
# 25%                      4.000000                  2.000000
# 50%                      8.000000                  3.000000
# 75%                     12.000000                  4.000000
# max                     15.000000                  5.000000
#
#        Company_Support_for_Remote_Work
# count                      2500.000000
# mean                          3.046400
# std                           1.404933
# min                           1.000000
# 25%                           2.000000
# 50%                           3.000000
# 75%                           4.000000
# max                           5.000000

# %% [raw]
# 2. Data Pre-processing
# under this step we Perform all necessary cleaning steps such as Handling missing values,Removing duplicates,Correcting data types,Creating derived columns,Filtering or aggregating data where necessary.

# %%
rw.isnull().sum()
# Out:
# Employee_ID                            0
# Age                                    2
# Gender                                 0
# Job_Role                               2
# Industry                               2
# Years_of_Experience                    3
# Work_Location                          3
# Hours_Worked_Per_Week                  6
# Number_of_Virtual_Meetings             4
# Work_Life_Balance_Rating               2
# Stress_Level                           0
# Mental_Health_Condition              595
# Access_to_Mental_Health_Resources      3
# Productivity_Change                    1
# Satisfaction_with_Remote_Work          3
# Company_Support_for_Remote_Work        0
# Physical_Activity                    833
# Sleep_Quality                          0
# Region                                 0
# dtype: int64

# %% [markdown]
# 2.1 Handling missing numerical values with mean:

# %%
rw['Age']=rw['Age'].fillna(rw['Age'].mean())
rw['Years_of_Experience']=rw['Years_of_Experience'].fillna(rw['Years_of_Experience'].mean())
rw['Hours_Worked_Per_Week']=rw['Hours_Worked_Per_Week'].fillna(rw['Hours_Worked_Per_Week'].mean())
rw['Number_of_Virtual_Meetings']=rw['Number_of_Virtual_Meetings'].fillna(rw['Number_of_Virtual_Meetings'].mean())
rw['Work_Life_Balance_Rating']=rw['Work_Life_Balance_Rating'].fillna(rw['Work_Life_Balance_Rating'].mean())

# %% [markdown]
# 2.11 Handling missing categorical values with mode:

# %%
rw['Job_Role']=rw['Job_Role'].fillna(rw['Job_Role'].mode()[0])
rw['Industry']=rw['Industry'].fillna(rw['Industry'].mode()[0])
rw['Work_Location']=rw['Work_Location'].fillna(rw['Work_Location'].mode()[0])
rw['Mental_Health_Condition']=rw['Mental_Health_Condition'].fillna(rw['Mental_Health_Condition'].mode()[0])
rw['Access_to_Mental_Health_Resources']=rw['Access_to_Mental_Health_Resources'].fillna(rw['Access_to_Mental_Health_Resources'].mode()[0])
rw['Productivity_Change']=rw['Productivity_Change'].fillna(rw['Productivity_Change'].mode()[0])
rw['Satisfaction_with_Remote_Work']=rw['Satisfaction_with_Remote_Work'].fillna(rw['Satisfaction_with_Remote_Work'].mode()[0])
rw['Physical_Activity']=rw['Physical_Activity'].fillna(rw['Physical_Activity'].mode()[0])

# %%
rw.isnull().sum()
# Out:
# Employee_ID                          0
# Age                                  0
# Gender                               0
# Job_Role                             0
# Industry                             0
# Years_of_Experience                  0
# Work_Location                        0
# Hours_Worked_Per_Week                0
# Number_of_Virtual_Meetings           0
# Work_Life_Balance_Rating             0
# Stress_Level                         0
# Mental_Health_Condition              0
# Access_to_Mental_Health_Resources    0
# Productivity_Change                  0
# Satisfaction_with_Remote_Work        0
# Company_Support_for_Remote_Work      0
# Physical_Activity                    0
# Sleep_Quality                        0
# Region                               0
# dtype: int64

# %% [markdown]
# 2.2 Removing Duplicates

# %%
rw.duplicated().sum()
# Out:
# np.int64(1)

# %%
rw.drop_duplicates()
# Out:
#      Employee_ID   Age             Gender           Job_Role    Industry  \
# 0        EMP0001  32.0         Non-binary                 HR  Healthcare
# 1        EMP0002  40.0             Female     Data Scientist          IT
# 2        EMP0003  59.0         Non-binary  Software Engineer   Education
# 3        EMP0004  27.0               Male  Software Engineer     Finance
# 4        EMP0005  49.0               Male              Sales  Consulting
# ...          ...   ...                ...                ...         ...
# 2494     EMP2495  45.0  Prefer not to say    Project Manager   Education
# 2495     EMP2496  31.0               Male     Data Scientist          IT
# 2496     EMP2497  55.0  Prefer not to say  Software Engineer   Education
# 2497     EMP2498  47.0               Male    Project Manager          IT
# 2498     EMP2499  56.0             Female     Data Scientist  Healthcare
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                    13.0        Hybrid                   47.0
# 1                     3.0        Remote                   52.0
# 2                    22.0        Hybrid                   46.0
# 3                    20.0        Onsite                   32.0
# 4                    32.0        Onsite                   35.0
# ...                   ...           ...                    ...
# 2494                 16.0        Onsite                   42.0
# 2495                 20.0        Onsite                   48.0
# 2496                 15.0        Onsite                   41.0
# 2497                 19.0        Onsite                   27.0
# 2498                 18.0        Remote                   21.0
#
#       Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                       7.000000                       2.0       Medium
# 1                       4.000000                       1.0       Medium
# 2                       7.602564                       5.0       Medium
# 3                       8.000000                       4.0         High
# 4                      12.000000                       2.0         High
# ...                          ...                       ...          ...
# 2494                    0.000000                       2.0          Low
# 2495                    0.000000                       1.0         High
# 2496                   15.000000                       3.0          Low
# 2497                    7.000000                       3.0          Low
# 2498                   13.000000                       2.0       Medium
#
#      Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0                 Depression                                No
# 1                    Anxiety                                No
# 2                    Anxiety                                No
# 3                 Depression                               Yes
# 4                    Burnout                               Yes
# ...                      ...                               ...
# 2494              Depression                                No
# 2495                 Anxiety                               Yes
# 2496                 Anxiety                                No
# 2497                 Burnout                               Yes
# 2498              Depression                                No
#
#      Productivity_Change Satisfaction_with_Remote_Work  \
# 0               Decrease                   Unsatisfied
# 1               Increase                     Satisfied
# 2              No Change                   Unsatisfied
# 3               Increase                   Unsatisfied
# 4               Decrease                   Unsatisfied
# ...                  ...                           ...
# 2494           No Change                     Satisfied
# 2495            Increase                   Unsatisfied
# 2496           No Change                   Unsatisfied
# 2497            Increase                       Neutral
# 2498            Increase                       Neutral
#
#       Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                   1            Weekly          Good
# 1                                   2            Weekly          Good
# 2                                   5            Weekly          Poor
# 3                                   3            Weekly          Poor
# 4                                   3            Weekly       Average
# ...                               ...               ...           ...
# 2494                                4             Daily          Good
# 2495                                3             Daily          Good
# 2496                                5            Weekly          Good
# 2497                                4            Weekly       Average
# 2498                                3             Daily          Good
#
#              Region
# 0            Europe
# 1              Asia
# 2     North America
# 3            Europe
# 4     North America
# ...             ...
# 2494  South America
# 2495           Asia
# 2496        Oceania
# 2497  South America
# 2498        Oceania
#
# [2499 rows x 19 columns]

# %% [markdown]
# 2.3 Correcting Data Type

# %%
rw['Age']=rw['Age'].astype(int)
rw['Years_of_Experience']=rw['Years_of_Experience'].astype(int)
rw['Number_of_Virtual_Meetings']=rw['Number_of_Virtual_Meetings'].astype(int)
rw['Work_Life_Balance_Rating']=rw['Work_Life_Balance_Rating'].astype(int)

# %% [markdown]
# 2.4 Creating Derived Column

# %%
rw['work load by age'] = rw['Hours_Worked_Per_Week']/rw['Age']

# %% [markdown]
# 2.4 Filtering Data

# %%
rw['high work']=rw['Number_of_Virtual_Meetings']>=8

# %% [markdown]
# 2.4 Aggregating Data

# %%
rw.groupby('Work_Location')['Industry'].unique()
# Out:
# Work_Location
# Hybrid    [Healthcare, Education, IT, Consulting, Manufa...
# Onsite    [Finance, Consulting, Manufacturing, Education...
# Remote    [IT, Finance, Consulting, Retail, Healthcare, ...
# Name: Industry, dtype: object

# %% [markdown]
# 3.Exploratory Data Analysis (EDA)
# simplifies data by descriptive and exploratory analysis to uncover patterns and trends Univariate, bivariate, and multivariate analysis,Using groupby, pivot tables and correlation analysis by Including statistical summaries to support findings generated.

# %% [markdown]
# 3.1 Univariate, bivariate, and multivariate analysis

# %%
#univariate
df_counts = rw['Work_Location'].value_counts().reset_index()
df_counts
# Out:
#   Work_Location  count
# 0        Remote    884
# 1        Hybrid    839
# 2        Onsite    777

# %%
#bivariate
df_group=rw.groupby('Age')['Hours_Worked_Per_Week'].mean().reset_index()
df_group
# Out:
#     Age  Hours_Worked_Per_Week
# 0    22              39.305085
# 1    23              39.191176
# 2    24              38.160494
# 3    25              38.391304
# 4    26              39.981481
# 5    27              40.068966
# 6    28              41.432836
# 7    29              38.745098
# 8    30              41.171429
# 9    31              39.509434
# 10   32              39.239437
# 11   33              39.500000
# 12   34              40.054545
# 13   35              37.724138
# 14   36              37.666667
# 15   37              41.363636
# 16   38              37.950820
# 17   39              39.920635
# 18   40              40.571429
# 19   41              39.545455
# 20   42              39.426829
# 21   43              40.159897
# 22   44              39.959184
# 23   45              38.468354
# 24   46              39.966667
# 25   47              39.907866
# 26   48              40.236111
# 27   49              38.158730
# 28   50              40.214286
# 29   51              40.490895
# 30   52              35.081967
# 31   53              39.219178
# 32   54              38.643998
# 33   55              39.415094
# 34   56              40.869565
# 35   57              39.887324
# 36   58              38.958904
# 37   59              39.350327
# 38   60              41.330470

# %%
#multivariate
rw[['Job_Role','Work_Location','Stress_Level']].head()
# Out:
#             Job_Role Work_Location Stress_Level
# 0                 HR        Hybrid       Medium
# 1     Data Scientist        Remote       Medium
# 2  Software Engineer        Hybrid       Medium
# 3  Software Engineer        Onsite         High
# 4              Sales        Onsite         High

# %% [markdown]
# 3.2  Groupby,Pivot tables and Correlation Analysis

# %%
# Average work hour by industry
df_avg=rw.groupby('Industry')['Hours_Worked_Per_Week'].mean().reset_index()
df_avg
# Out:
#         Industry  Hours_Worked_Per_Week
# 0     Consulting              39.111111
# 1      Education              39.147331
# 2        Finance              39.076726
# 3     Healthcare              39.855978
# 4             IT              40.028456
# 5  Manufacturing              39.773357
# 6         Retail              39.312000

# %%
#pivot table 
pd.pivot_table(rw,values='Stress_Level',index='Work_Location',columns='Gender', aggfunc='max')
# Out:
# Gender         Female    Male Non-binary Prefer not to say
# Work_Location
# Hybrid         Medium  Medium     Medium            Medium
# Onsite         Medium  Medium     Medium            Medium
# Remote         Medium  Medium     Medium            Medium

# %%
#correlation analysis
corr = rw.corr(numeric_only=True)
print(corr)
# Out:
#                                       Age  Years_of_Experience  \
# Age                              1.000000             0.009078
# Years_of_Experience              0.009078             1.000000
# Hours_Worked_Per_Week            0.005324            -0.024019
# Number_of_Virtual_Meetings       0.025781             0.015714
# Work_Life_Balance_Rating        -0.005516            -0.017741
# Company_Support_for_Remote_Work  0.025374             0.003998
# work load by age                -0.674086            -0.031082
# high work                        0.028203             0.017976
#
#                                  Hours_Worked_Per_Week  \
# Age                                           0.005324
# Years_of_Experience                          -0.024019
# Hours_Worked_Per_Week                         1.000000
# Number_of_Virtual_Meetings                    0.011345
# Work_Life_Balance_Rating                     -0.007294
# Company_Support_for_Remote_Work               0.009575
# work load by age                              0.681798
# high work                                     0.002886
#
#                                  Number_of_Virtual_Meetings  \
# Age                                                0.025781
# Years_of_Experience                                0.015714
# Hours_Worked_Per_Week                              0.011345
# Number_of_Virtual_Meetings                         1.000000
# Work_Life_Balance_Rating                          -0.007491
# Company_Support_for_Remote_Work                   -0.009057
# work load by age                                  -0.000713
# high work                                          0.862035
#
#                                  Work_Life_Balance_Rating  \
# Age                                             -0.005516
# Years_of_Experience                             -0.017741
# Hours_Worked_Per_Week                           -0.007294
# Number_of_Virtual_Meetings                      -0.007491
# Work_Life_Balance_Rating                         1.000000
# Company_Support_for_Remote_Work                 -0.011660
# work load by age                                -0.003566
# high work                                       -0.015773
#
#                                  Company_Support_for_Remote_Work  \
# Age                                                     0.025374
# Years_of_Experience                                     0.003998
# Hours_Worked_Per_Week                                   0.009575
# Number_of_Virtual_Meetings                             -0.009057
# Work_Life_Balance_Rating                               -0.011660
# Company_Support_for_Remote_Work                         1.000000
# work load by age                                       -0.007862
# high work                                               0.010120
#
#                                  work load by age  high work
# Age                                     -0.674086   0.028203
# Years_of_Experience                     -0.031082   0.017976
# Hours_Worked_Per_Week                    0.681798   0.002886
# Number_of_Virtual_Meetings              -0.000713   0.862035
# Work_Life_Balance_Rating                -0.003566  -0.015773
# Company_Support_for_Remote_Work         -0.007862   0.010120
# work load by age                         1.000000  -0.013754
# high work                               -0.013754   1.000000

# %%
#correlation map
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("CORRELATION HEATMAP")
plt.show()

# %% [markdown]
# 3.1 statistical summaries

# %%
rw_columns=rw[['Age','Work_Location','Hours_Worked_Per_Week','Job_Role','Stress_Level','Industry','Gender']]
# Overall statistical summary
print("\nOverall Summary:\n")
print(rw_columns['Work_Location'].describe())

# Statistical summary as job role and their stress
print("\nSummary as job role and their stress:\n")
print(rw_columns.groupby('Job_Role')['Stress_Level'].describe())

# Statistical summary as hours of work by industry 
print("\nSummary as hours of work by industry:\n")
print(rw_columns.groupby('Industry')['Hours_Worked_Per_Week'].describe())
# Out:
# Overall Summary:
#
# count       2500
# unique         3
# top       Remote
# freq         884
# Name: Work_Location, dtype: object
#
# Summary as job role and their stress:
#
#                   count unique     top freq
# Job_Role
# Data Scientist      332      3    High  127
# Designer            371      3     Low  134
# HR                  342      3  Medium  124
# Marketing           355      3     Low  128
# Project Manager     354      3  Medium  123
# Sales               358      3  Medium  123
# Software Engineer   388      3  Medium  134
#
# Summary as hours of work by industry:
#
#                count       mean        std   min   25%        50%   75%   max
# Industry
# Consulting     342.0  39.111111  11.711059  20.0  30.0  38.000000  50.0  60.0
# Education      329.0  39.147331  11.764597  20.0  29.0  39.000000  49.0  60.0
# Finance        391.0  39.076726  11.399246  20.0  28.0  39.000000  48.0  60.0
# Healthcare     368.0  39.855978  11.598573  20.0  29.0  40.000000  49.0  60.0
# IT             368.0  40.028456  11.893829  20.0  29.0  40.000000  50.0  60.0
# Manufacturing  327.0  39.773357  12.471602  20.0  28.0  39.471933  51.0  60.0
# Retail         375.0  39.312000  11.978199  20.0  29.0  38.000000  50.0  60.0
